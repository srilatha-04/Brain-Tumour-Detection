# %% [markdown]
# # Library calls

# %%
import pandas as pd 
import numpy as np  
import seaborn as sns 
import matplotlib.pyplot as  plt 
import cv2
import tensorflow as tf 
from tensorflow.keras.layers import Dense,Dropout,BatchNormalization,Conv2D,MaxPooling2D,Flatten,InputLayer,Input
from tensorflow.keras.callbacks import EarlyStopping,LearningRateScheduler,ModelCheckpoint
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras.applications import ResNet152V2,DenseNet121,InceptionResNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.metrics import Accuracy,TruePositives,TrueNegatives,FalseNegatives,FalsePositives
from tensorflow.keras.regularizers import L2
from sklearn.metrics import confusion_matrix,classification_report,roc_curve,roc_auc_score

# %% [markdown]
# # Load the dataset

# %%
directory = '/kaggle/input/brain-mri-images-for-brain-tumor-detection'

# %%
class_names = ['no','yes']

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    directory,
    labels='inferred',
    label_mode='int',
    class_names=class_names,
    color_mode='rgb',
    batch_size=None,
    image_size=(256, 256),
    shuffle=True,
    seed=42
)
# Out:
# Found 253 files belonging to 2 classes.

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## splits

# %%
def splits(dataset,Train_ratio,Val_ratio,Test_ratio):
    
    data_size = len(dataset)
    
    train_dataset = dataset.take(int(data_size*Train_ratio))
    
    val_split_set = dataset.skip(int(data_size*Train_ratio))
    
    val_dataset = val_split_set.take((int(data_size*Val_ratio)))
    
    test_dataset = val_split_set.skip(int(data_size*Test_ratio))
    return train_dataset,val_dataset,test_dataset 

Train_ratio = 0.80 
Val_ratio = .10
Test_ratio = 0.10
train_dataset,val_dataset,test_dataset  = splits(dataset,Train_ratio,Val_ratio,Test_ratio)

print("The length of the train_dataset is  : ",len(train_dataset))
print('The length of the val_dataset is  : ',len(val_dataset))
print('The length of the test_dataset is  : ',len(test_dataset))
# Out:
# The length of the train_dataset is  :  202
# The length of the val_dataset is  :  25
# The length of the test_dataset is  :  26

# %% [markdown]
# ## visualize some image

# %%
plt.figure(figsize=(8,8))
for i,(image,label) in enumerate(train_dataset.take(9)):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(image/255)
    plt.title(class_names[label])
    plt.axis('off')

# %% [markdown]
# ## Dataset prepraration

# %%
#  resize and rescaling

def resize_rescaling(image,label):
    
    return tf.image.resize(image,(224,224))/255,label

# %%
train_dataset = (
             train_dataset
            .shuffle(reshuffle_each_iteration=True,buffer_size=8)
            .map(resize_rescaling)
            .batch(10)
            .prefetch(tf.data.AUTOTUNE)
)

# %%
val_dataset = (
             val_dataset
            .shuffle(reshuffle_each_iteration=True,buffer_size=8)
            .map(resize_rescaling)
            .batch(3)
            .prefetch(tf.data.AUTOTUNE)
)

# %%
test_dataset = (
             test_dataset
            .shuffle(reshuffle_each_iteration=True,buffer_size=8)
            .map(resize_rescaling)
            .batch(1)
            .prefetch(tf.data.AUTOTUNE)
)

# %% [markdown]
# # Create  a model

# %%
Lenet_model = tf.keras.Sequential([
    InputLayer(shape=(224,224,3)),
    
    Conv2D(filters=32, kernel_size=3,strides=2,padding='valid',activation='relu',kernel_regularizer=L2(0.01)),
    Dropout(0.2),
    BatchNormalization(),
    MaxPooling2D(pool_size=3,strides=2),

    Conv2D(filters=32,kernel_size=3,strides=2,padding='valid',activation='relu',kernel_regularizer=L2(0.01)),
    
    BatchNormalization(),
    MaxPooling2D(pool_size=3,strides=1),
    
    Conv2D(filters=32,kernel_size=3,strides=2,padding='valid',activation='relu',kernel_regularizer=L2(0.01)),
    
    BatchNormalization(),

    MaxPooling2D(pool_size=3,strides=1),
    Dropout(0.2),
    

    Flatten(),
    
    Dense(64,activation='relu'),
    BatchNormalization(),
    
    Dense(64,activation='relu'),
    BatchNormalization(),
    
    Dense(1,activation='sigmoid')
],name='Lenet_model')
Lenet_model.summary()
# Out:
# Model: "Lenet_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 111, 111, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 111, 111, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 55, 55, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 27, 27, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 27, 27, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 25, 25, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 12, 12, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3200)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       204,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 229,377 (896.00 KB)
#  Trainable params: 228,929 (894.25 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
Lenet_model.compile(loss = BinaryCrossentropy(),
                   optimizer=Adam(learning_rate=0.001),
                   metrics = ['accuracy'])

# %%
checkpoint_path = "/kaggle/working/best_model.keras"  # Change the extension to .h5
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,  # Corrected parameter name and file extension
    monitor='val_loss',  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode='min',  # 'min' for loss, 'max' for accuracy
    verbose=1
)


early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=30, 
    verbose=1,
    mode='auto',
    restore_best_weights=True
)

# %%
history = Lenet_model.fit(train_dataset,
                          validation_data=val_dataset,
                          epochs=30,
                          verbose=1,
                          callbacks = [checkpoint_callback,
                                      early_stopping ]
                       
                         )
# Out:
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740049015.128541      71 service.cc:145] XLA service 0x7d7010007200 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740049015.128607      71 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6621 - loss: 1.4343
# I0000 00:00:1740049020.890702      71 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.6663 - loss: 1.4104
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740049025.540590      72 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_2', 172 bytes spill stores, 212 bytes spill loads
# Epoch 1: val_loss improved from inf to 1.36309, saving model to /kaggle/working/best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 15s 307ms/step - accuracy: 0.6666 - loss: 1.4076 - val_accuracy: 0.4800 - val_loss: 1.3631
# Epoch 2/30
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7816 - loss: 1.1658
# Epoch 2: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7817 - loss: 1.1684 - val_accuracy: 0.4400 - val_loss: 1.3818
# Epoch 3/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7559 - loss: 1.1012
# Epoch 3: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7602 - loss: 1.1015 - val_accuracy: 0.4800 - val_loss: 1.4744
# Epoch 4/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7543 - loss: 1.1454
# Epoch 4: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.7632 - loss: 1.1341 - val_accuracy: 0.4400 - val_loss: 2.1367
# Epoch 5/30
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8641 - loss: 1.0305
# Epoch 5: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8574 - loss: 1.0370 - val_accuracy: 0.4000 - val_loss: 3.3029
# Epoch 6/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8816 - loss: 1.0004
# Epoch 6: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8726 - loss: 1.0153 - val_accuracy: 0.2400 - val_loss: 5.4879
# Epoch 7/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7897 - loss: 1.0328
# Epoch 7: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7887 - loss: 1.0317 - val_accuracy: 0.3600 - val_loss: 3.5797
# Epoch 8/30
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8366 - loss: 1.0230
# Epoch 8: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8386 - loss: 1.0145 - val_accuracy: 0.4000 - val_loss: 4.1009
# Epoch 9/30
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8649 - loss: 0.9527
# Epoch 9: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8663 - loss: 0.9552 - val_accuracy: 0.4400 - val_loss: 3.8077
# Epoch 10/30
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8829 - loss: 0.8831
# Epoch 10: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8826 - loss: 0.8929 - val_accuracy: 0.2000 - val_loss: 4.7019
# Epoch 11/30
# 15/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8847 - loss: 0.8990
# Epoch 11: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8838 - loss: 0.9053 - val_accuracy: 0.4400 - val_loss: 2.6013
# Epoch 12/30
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9161 - loss: 0.8410
# Epoch 12: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9137 - loss: 0.8451 - val_accuracy: 0.2800 - val_loss: 4.2673
# Epoch 13/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8913 - loss: 0.8718
# Epoch 13: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8869 - loss: 0.8830 - val_accuracy: 0.4400 - val_loss: 2.8105
# Epoch 14/30
# 19/21 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9413 - loss: 0.8351
# Epoch 14: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9360 - loss: 0.8420 - val_accuracy: 0.2400 - val_loss: 2.9963
# Epoch 15/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8854 - loss: 0.8671
# Epoch 15: val_loss did not improve from 1.36309
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8900 - loss: 0.8591 - val_accuracy: 0.3200 - val_loss: 2.0048
# Epoch 16/30
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9186 - loss: 0.8074
# Epoch 16: val_loss improved from 1.36309 to 1.08139, saving model to /kaggle/working/best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9194 - loss: 0.8048 - val_accuracy: 0.8000 - val_loss: 1.0814
# Epoch 17/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8895 - loss: 0.8256
# Epoch 17: val_loss did not improve from 1.08139
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8867 - loss: 0.8356 - val_accuracy: 0.4800 - val_loss: 1.7620
# Epoch 18/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9336 - loss: 0.8083
# Epoch 18: val_loss did not improve from 1.08139
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9340 - loss: 0.8024 - val_accuracy: 0.5200 - val_loss: 1.6972
# Epoch 19/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9516 - loss: 0.7800
# Epoch 19: val_loss did not improve from 1.08139
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9444 - loss: 0.7902 - val_accuracy: 0.7200 - val_loss: 1.3004
# Epoch 20/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9280 - loss: 0.8027
# Epoch 20: val_loss improved from 1.08139 to 1.00162, saving model to /kaggle/working/best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9318 - loss: 0.7920 - val_accuracy: 0.8800 - val_loss: 1.0016
# Epoch 21/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9077 - loss: 0.8337
# Epoch 21: val_loss improved from 1.00162 to 0.96687, saving model to /kaggle/working/best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9018 - loss: 0.8471 - val_accuracy: 0.8400 - val_loss: 0.9669
# Epoch 22/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8199 - loss: 0.9150
# Epoch 22: val_loss did not improve from 0.96687
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8145 - loss: 0.9278 - val_accuracy: 0.8000 - val_loss: 1.2451
# Epoch 23/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8594 - loss: 0.8961
# Epoch 23: val_loss did not improve from 0.96687
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8631 - loss: 0.9031 - val_accuracy: 0.8000 - val_loss: 1.3298
# Epoch 24/30
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8264 - loss: 0.9145
# Epoch 24: val_loss did not improve from 0.96687
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8278 - loss: 0.9154 - val_accuracy: 0.6800 - val_loss: 1.3185
# Epoch 25/30
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8625 - loss: 0.8802
# Epoch 25: val_loss did not improve from 0.96687
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8650 - loss: 0.8783 - val_accuracy: 0.8400 - val_loss: 1.0558
# Epoch 26/30
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8833 - loss: 0.8806
# Epoch 26: val_loss did not improve from 0.96687
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8822 - loss: 0.8888 - val_accuracy: 0.6800 - val_loss: 2.1118
# Epoch 27/30
# 16/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9298 - loss: 0.7820
# Epoch 27: val_loss improved from 0.96687 to 0.93021, saving model to /kaggle/working/best_model.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9330 - loss: 0.7840 - val_accuracy: 0.8800 - val_loss: 0.9302
# Epoch 28/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9304 - loss: 0.8140
# Epoch 28: val_loss did not improve from 0.93021
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9289 - loss: 0.8145 - val_accuracy: 0.6800 - val_loss: 1.4421
# Epoch 29/30
# 18/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9061 - loss: 0.8057
# Epoch 29: val_loss did not improve from 0.93021
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9037 - loss: 0.8095 - val_accuracy: 0.8800 - val_loss: 0.9355
# Epoch 30/30
# 17/21 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8772 - loss: 0.8598
# Epoch 30: val_loss did not improve from 0.93021
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8825 - loss: 0.8505 - val_accuracy: 0.7600 - val_loss: 1.1753
# Restoring model weights from the end of the best epoch: 27.

# %% [markdown]
# ## Evaluate the model

# %%
def evaluate_model(model,dataset):
    
    loss = model.history.history['loss']
    val_loss = model.history.history['val_loss']
    accuracy = model.history.history['accuracy']
    val_accuracy = model.history.history['val_accuracy']
    
    plt.figure(figsize=(14,12))
    
    # Plot model loss 
    plt.subplot(2,2,1)
  
    plt.plot(val_loss)
    plt.title("Model Loss")
    plt.xlabel("Epochs")
    plt.ylabel('Loss')
    plt.legend(['train_loss','val_loss'])
    plt.grid()

    # Plot model accuracy
    plt.subplot(2,2,2)
   
    plt.plot(accuracy)
    plt.plot(val_accuracy)
    plt.title("Model Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel('Accuracy')
    plt.legend(['train_accuracy','val_accuracy'])
    plt.grid()
    
    # confusion matrix
    plt.subplot(2,2,3)
    
    img = []
    labels = []
    for x,y in dataset:
        img.append(x)
        labels.append(y)
    true_label = np.array(labels).flatten()
    predicted = model.predict(np.array(img)[:,0,...])[:,0]
    
    threshold = 0.5

    cm = confusion_matrix(true_label, predicted > threshold)
   
  

    sns.heatmap(cm, annot=True,cmap='Blues',xticklabels=['NO','YES'],yticklabels=['NO','YES'])
    plt.title('Confusion matrix - {}'.format(threshold))
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    
    # Plot roc curve
    plt.subplot(2,2,4)

    fp, tp, thresholds = roc_curve(true_label, predicted)
    roc_auc = roc_auc_score(true_label,predicted)
    plt.plot(fp,tp, color='blue',  label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0,1],[0,1],linestyle='--')
    plt.xlabel("False Positive rate")
    plt.ylabel("True Positive rate")

    plt.grid()

    skip = 2

    for i in range(0, len(thresholds), skip):
      plt.text(fp[i], tp[i], thresholds[i])
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# %%
evaluate_model(Lenet_model,test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step

# %%
test_evaluate = Lenet_model.evaluate(test_dataset)
test_evaluate
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7877 - loss: 0.9796
# [1.0155398845672607, 0.7307692170143127]

# %%
val_evaluate = Lenet_model.evaluate(val_dataset)
val_evaluate
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8717 - loss: 0.9630
# [0.9942046999931335, 0.8399999737739563]

# %% [markdown]
# # Transform Learning

# %% [markdown]
# ## ResNet152V2

# %%
resnet_backbone = ResNet152V2(
    include_top=False,
    weights='imagenet',
    input_shape= (224,224,3)
)
inputs = Input(shape=(224,224,3))
x = resnet_backbone(inputs)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
outputs = Dense(1,activation='sigmoid')(x)
Resnet_model = Model(inputs,outputs,name='Resnet_model')
Resnet_model.compile(loss = BinaryCrossentropy(),
                   optimizer=Adam(learning_rate=0.0001),
                   metrics = ['accuracy'])
Resnet_model.fit(train_dataset,
                          validation_data=val_dataset,
                          epochs=25,
                          verbose=1
                       
                         )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/25
# I0000 00:00:1740049216.247721      73 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_38', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_21', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_5', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_46', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_43', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 4 bytes spill stores, 12 bytes spill loads
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.6315 - loss: 0.6326
# I0000 00:00:1740049312.068488      72 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_62', 432 bytes spill stores, 468 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 44 bytes spill stores, 44 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_5', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_41', 4 bytes spill stores, 12 bytes spill loads
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 277s 5s/step - accuracy: 0.6416 - loss: 0.6201 - val_accuracy: 0.4400 - val_loss: 1.5401
# Epoch 2/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.8804 - loss: 0.3205 - val_accuracy: 0.7600 - val_loss: 0.3789
# Epoch 3/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.9293 - loss: 0.1934 - val_accuracy: 0.7600 - val_loss: 0.5206
# Epoch 4/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.9763 - loss: 0.1375 - val_accuracy: 0.8000 - val_loss: 0.6033
# Epoch 5/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.9754 - loss: 0.1431 - val_accuracy: 0.9600 - val_loss: 0.0667
# Epoch 6/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9796 - loss: 0.1043 - val_accuracy: 0.9600 - val_loss: 0.0713
# Epoch 7/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9585 - loss: 0.1209 - val_accuracy: 1.0000 - val_loss: 0.0633
# Epoch 8/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.9575 - loss: 0.1334 - val_accuracy: 0.9600 - val_loss: 0.1084
# Epoch 9/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9479 - loss: 0.1499 - val_accuracy: 0.9600 - val_loss: 0.1354
# Epoch 10/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9553 - loss: 0.1332 - val_accuracy: 0.8800 - val_loss: 0.6143
# Epoch 11/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9804 - loss: 0.1003 - val_accuracy: 0.9600 - val_loss: 0.3918
# Epoch 12/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.9668 - loss: 0.0861 - val_accuracy: 0.9200 - val_loss: 0.1882
# Epoch 13/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.9794 - loss: 0.1073 - val_accuracy: 1.0000 - val_loss: 0.1090
# Epoch 14/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9393 - loss: 0.1429 - val_accuracy: 0.8000 - val_loss: 0.4062
# Epoch 15/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9146 - loss: 0.2697 - val_accuracy: 0.8800 - val_loss: 0.2861
# Epoch 16/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9678 - loss: 0.1038 - val_accuracy: 1.0000 - val_loss: 0.0993
# Epoch 17/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9827 - loss: 0.1083 - val_accuracy: 1.0000 - val_loss: 0.0734
# Epoch 18/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9609 - loss: 0.1115 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 19/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9906 - loss: 0.0531 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 20/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9689 - loss: 0.0900 - val_accuracy: 1.0000 - val_loss: 0.0260
# Epoch 21/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.9364 - loss: 0.1145 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 22/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.9758 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 23/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.9722 - loss: 0.0765 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 24/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9892 - loss: 0.0629 - val_accuracy: 0.7200 - val_loss: 5.4697
# Epoch 25/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9122 - loss: 0.1978 - val_accuracy: 0.4800 - val_loss: 0.9663

# %%
evaluate_model(Resnet_model,test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step

# %% [markdown]
# ## DenseNet121

# %%
DenseNet_backbone = DenseNet121(
    include_top=False,
    weights='imagenet',
    input_shape= (224,224,3)
)
inputs = Input(shape=(224,224,3))
x = DenseNet_backbone(inputs)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
outputs = Dense(1,activation='sigmoid')(x)
Densenet_model = Model(inputs,outputs,name='Resnet_model')
Densenet_model.compile(loss = BinaryCrossentropy(),
                   optimizer=Adam(learning_rate=0.0001),
                   metrics = ['accuracy'])
Densenet_model.fit(train_dataset,
                          validation_data=val_dataset,
                          epochs=25,
                          verbose=1
                       
                         )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/25
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6079 - loss: 0.6919
# I0000 00:00:1740049653.463219      73 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion', 156 bytes spill stores, 184 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_compare_reduce_fusion_38', 4 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_20', 20 bytes spill stores, 20 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_21', 48 bytes spill stores, 48 bytes spill loads
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 238s 5s/step - accuracy: 0.6193 - loss: 0.6803 - val_accuracy: 0.5200 - val_loss: 0.9689
# Epoch 2/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.9181 - loss: 0.2533 - val_accuracy: 0.5600 - val_loss: 0.9170
# Epoch 3/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9341 - loss: 0.2072 - val_accuracy: 0.7200 - val_loss: 0.7582
# Epoch 4/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9549 - loss: 0.1495 - val_accuracy: 0.8000 - val_loss: 0.3082
# Epoch 5/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 0.9620 - loss: 0.1632 - val_accuracy: 0.7600 - val_loss: 0.3308
# Epoch 6/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9930 - loss: 0.0977 - val_accuracy: 0.8800 - val_loss: 0.2222
# Epoch 7/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9863 - loss: 0.0782 - val_accuracy: 0.9200 - val_loss: 0.2916
# Epoch 8/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.9492 - loss: 0.1186 - val_accuracy: 1.0000 - val_loss: 0.1120
# Epoch 9/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9984 - loss: 0.0566 - val_accuracy: 0.9600 - val_loss: 0.0944
# Epoch 10/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9961 - loss: 0.0477 - val_accuracy: 1.0000 - val_loss: 0.0682
# Epoch 11/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9309 - loss: 0.2058 - val_accuracy: 1.0000 - val_loss: 0.0974
# Epoch 12/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9832 - loss: 0.0894 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 13/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 1.0000 - loss: 0.0329 - val_accuracy: 0.9600 - val_loss: 0.1099
# Epoch 14/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9901 - loss: 0.0404 - val_accuracy: 1.0000 - val_loss: 0.0893
# Epoch 15/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9711 - loss: 0.1098 - val_accuracy: 0.6800 - val_loss: 0.5617
# Epoch 16/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9761 - loss: 0.1394 - val_accuracy: 0.9200 - val_loss: 0.2268
# Epoch 17/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9842 - loss: 0.0939 - val_accuracy: 0.9200 - val_loss: 0.1468
# Epoch 18/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9932 - loss: 0.0651 - val_accuracy: 1.0000 - val_loss: 0.0813
# Epoch 19/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9908 - loss: 0.0675 - val_accuracy: 1.0000 - val_loss: 0.1090
# Epoch 20/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9773 - loss: 0.0959 - val_accuracy: 0.7600 - val_loss: 0.3316
# Epoch 21/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9579 - loss: 0.1469 - val_accuracy: 0.8800 - val_loss: 0.2430
# Epoch 22/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.9677 - loss: 0.1244 - val_accuracy: 0.8800 - val_loss: 0.3071
# Epoch 23/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.9321 - loss: 0.1618 - val_accuracy: 0.9600 - val_loss: 0.2094
# Epoch 24/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.9606 - loss: 0.1319 - val_accuracy: 0.8400 - val_loss: 0.2834
# Epoch 25/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.9980 - loss: 0.0427 - val_accuracy: 1.0000 - val_loss: 0.0412

# %%
evaluate_model(Densenet_model,test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %% [markdown]
# ## InceptionResNetV2

# %%
InceptResnet_backbone = InceptionResNetV2(
    include_top=False,
    weights='imagenet',
    input_shape= (224,224,3)
)
inputs = Input(shape=(224,224,3))
x = InceptResnet_backbone (inputs)
x = Flatten()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
x = Dense(64,activation='relu')(x)
x = BatchNormalization()(x)
outputs = Dense(1,activation='sigmoid')(x)
InceptResnet_model = Model(inputs,outputs,name='Resnet_model')
InceptResnet_model.compile(loss = BinaryCrossentropy(),
                   optimizer=Adam(learning_rate=0.0001),
                   metrics = ['accuracy'])
InceptResnet_model.fit(train_dataset,
                          validation_data=val_dataset,
                          epochs=25,
                          verbose=1
                       
                         )
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/25
# I0000 00:00:1740049929.591907      72 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_58', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_7', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_3', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_154', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_153', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_6', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_4', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_113', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_60', 4 bytes spill stores, 12 bytes spill loads
# 20/21 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6694 - loss: 0.6338
# I0000 00:00:1740049993.981966      73 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion', 160 bytes spill stores, 160 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_reduce_select_fusion_1', 100 bytes spill stores, 100 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_216', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_192', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_191', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_110', 104 bytes spill stores, 132 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 24 bytes spill stores, 24 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_109', 440 bytes spill stores, 476 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function '__cuda_sm3x_div_rn_noftz_f32_slowpath', 12 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_183', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_182', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_148', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_146', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_144', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_139', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_136', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_123', 4 bytes spill stores, 12 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_122', 4 bytes spill stores, 12 bytes spill loads
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 270s 4s/step - accuracy: 0.6756 - loss: 0.6244 - val_accuracy: 0.6800 - val_loss: 1.3008
# Epoch 2/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.8863 - loss: 0.3769 - val_accuracy: 0.4000 - val_loss: 2.0006
# Epoch 3/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9009 - loss: 0.3303 - val_accuracy: 0.7600 - val_loss: 0.4625
# Epoch 4/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.9242 - loss: 0.1939 - val_accuracy: 0.8000 - val_loss: 0.4259
# Epoch 5/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9426 - loss: 0.1796 - val_accuracy: 0.9600 - val_loss: 0.1307
# Epoch 6/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9538 - loss: 0.1466 - val_accuracy: 0.9600 - val_loss: 0.1507
# Epoch 7/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.8800 - loss: 0.2910 - val_accuracy: 1.0000 - val_loss: 0.0627
# Epoch 8/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9664 - loss: 0.1426 - val_accuracy: 1.0000 - val_loss: 0.0921
# Epoch 9/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9728 - loss: 0.1033 - val_accuracy: 1.0000 - val_loss: 0.0532
# Epoch 10/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9711 - loss: 0.1203 - val_accuracy: 0.8800 - val_loss: 0.2443
# Epoch 11/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.8635 - loss: 0.2545 - val_accuracy: 0.8400 - val_loss: 0.5811
# Epoch 12/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9310 - loss: 0.1888 - val_accuracy: 0.7200 - val_loss: 0.5321
# Epoch 13/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.8434 - loss: 0.3664 - val_accuracy: 0.8800 - val_loss: 0.2339
# Epoch 14/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.9485 - loss: 0.1909 - val_accuracy: 1.0000 - val_loss: 0.1599
# Epoch 15/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 182ms/step - accuracy: 0.9989 - loss: 0.1123 - val_accuracy: 1.0000 - val_loss: 0.1491
# Epoch 16/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.9367 - loss: 0.1302 - val_accuracy: 1.0000 - val_loss: 0.1436
# Epoch 17/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9743 - loss: 0.1016 - val_accuracy: 0.9600 - val_loss: 0.1476
# Epoch 18/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9881 - loss: 0.0842 - val_accuracy: 1.0000 - val_loss: 0.0973
# Epoch 19/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9870 - loss: 0.0606 - val_accuracy: 0.7200 - val_loss: 0.4949
# Epoch 20/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9728 - loss: 0.1005 - val_accuracy: 0.9600 - val_loss: 0.1511
# Epoch 21/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 179ms/step - accuracy: 0.9465 - loss: 0.1655 - val_accuracy: 0.6000 - val_loss: 0.6590
# Epoch 22/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9228 - loss: 0.2528 - val_accuracy: 0.5200 - val_loss: 1.1002
# Epoch 23/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.9528 - loss: 0.1460 - val_accuracy: 0.8800 - val_loss: 0.2038
# Epoch 24/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.9818 - loss: 0.1075 - val_accuracy: 1.0000 - val_loss: 0.0371
# Epoch 25/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.9943 - loss: 0.1099 - val_accuracy: 1.0000 - val_loss: 0.0445

# %%
evaluate_model(InceptResnet_model,test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %% [markdown]
# # Test the a model

# %% [markdown]
# ## single prediction

# %%
def Tumor_or_Not(x):
    if x<.5:
        return str('no')
    else:
        return str('yes')

# %%
image = cv2.resize(cv2.imread('/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y101.jpg'),(224,224))
im   = tf.expand_dims(image,axis=0)
pred = Lenet_model.predict(im)[0][0]
print(Tumor_or_Not(pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# no

# %% [markdown]
# ## multiple prediction with visualize

# %%
plt.figure(figsize=(10,12))
for i,(image,label) in  enumerate(test_dataset.take(9)):
    ax = plt.subplot(3,3,i+1)
    plt.imshow(image[0])
    plt.title('True label : '+class_names[label[0]]+"\n"+'Predicted label : '+
             Tumor_or_Not(Lenet_model.predict(tf.expand_dims(image[0],axis=0))[0][0]))
    plt.axis('off')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# # Save and load the model

# %%
Lenet_model.save('Lenet_model.h5')

# %%
load_lenet = tf.keras.models.load_model('Lenet_model.h5')

# %%
# test our svae model
image = cv2.resize(cv2.imread('/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y101.jpg'),(224,224))
im   = tf.expand_dims(image,axis=0)
pred = load_lenet.predict(im)[0][0]
print(Tumor_or_Not(pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# no

# %%
# !pip install -U tf2onnx onnx
# !pip install onnxruntime
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Collecting tf2onnx
#   Downloading tf2onnx-1.16.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (1.17.0)
# Requirement already satisfied: numpy>=1.14.1 in /opt/conda/lib/python3.10/site-packages (from tf2onnx) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from tf2onnx) (2.32.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from tf2onnx) (1.16.0)
# Requirement already satisfied: flatbuffers>=1.12 in /opt/conda/lib/python3.10/site-packages (from tf2onnx) (24.3.25)
# Requirement already satisfied: protobuf~=3.20 in /opt/conda/lib/python3.10/site-packages (from tf2onnx) (3.20.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->tf2onnx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->tf2onnx) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->tf2onnx) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->tf2onnx) (2024.8.30)
# Downloading tf2onnx-1.16.1-py3-none-any.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: tf2onnx
# Successfully installed tf2onnx-1.16.1
# Collecting onnxruntime
#   Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime) (1.13.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime) (3.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.20.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 97.9 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.20.1

# %% [markdown]
# # load the model

# %%
# !mkdir /kaggle/working/Models/

# %%
# save tf format  
Lenet_model.export('/kaggle/working/Models/', format='onnx')
# Out:
# Saved artifact at '/kaggle/working/Models/'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   137921873869664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874022416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874022240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874020480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874021360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874019424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874026288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874019248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874027696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874029280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874026992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874020128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874028400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874031392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874032096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874347456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874032624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874029808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874346224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874347104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874350096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874352560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874349040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874350448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874349920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874352912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874355552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874358016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874351152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874355904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874358368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137921874357840: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
# !python -m tf2onnx.convert --saved-model /kaggle/working/Models/ --output Lenet_model.onnx --opset 13
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# /opt/conda/lib/python3.10/runpy.py:126: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2025-02-20 11:15:48,958 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2025-02-20 11:15:49,175 - INFO - Signatures found in model: [serve,serving_default].
# 2025-02-20 11:15:49,175 - WARNING - '--signature_def' not specified, using first signature: serve
# 2025-02-20 11:15:49,176 - INFO - Output names: ['output_0']
# 2025-02-20 11:15:49,377 - INFO - Using tensorflow=2.16.1, onnx=1.17.0, tf2onnx=1.16.1/15c810
# 2025-02-20 11:15:49,377 - INFO - Using opset <onnx, 13>
# 2025-02-20 11:15:49,391 - INFO - Computed 0 values for constant folding
# 2025-02-20 11:15:49,422 - INFO - Optimizing ONNX model
# 2025-02-20 11:15:49,531 - INFO - After optimization: Add -3 (11->8), Cast -1 (1->0), Identity -2 (2->0), Transpose -10 (12->2)
# 2025-02-20 11:15:49,534 - INFO -
# 2025-02-20 11:15:49,534 - INFO - Successfully converted TensorFlow model /kaggle/working/Models/ to ONNX
# 2025-02-20 11:15:49,534 - INFO - Model inputs: ['keras_tensor']
# 2025-02-20 11:15:49,534 - INFO - Model outputs: ['output_0']
# 2025-02-20 11:15:49,534 - INFO - ONNX model is saved at Lenet_model.onnx

# %%
import onnxruntime as nxrun
import numpy as np
from skimage.transform import resize
from skimage import io
import cv2
from tensorflow.keras.preprocessing.image import load_img
img = "/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y100.JPG"

image = load_img(img,target_size =(224,224))
image = np.float32(image)
ximg = np.expand_dims(image,0)

sess = nxrun.InferenceSession("/kaggle/working/Lenet_model.onnx")


input_name = sess.get_inputs()[0].name
label_name = sess.get_outputs()[0].name
result = sess.run([label_name], {input_name: ximg})
prob = result[0]
lab = np.argmax(prob,-1)
class_names[lab[0]]
# Out:
# 'no'
